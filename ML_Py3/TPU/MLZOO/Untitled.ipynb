# %%
start_values = {
    "bias_start": 16520,
    "calc_start": 1134,
    "output_start": 1918
}

groups_to_generate = 46
bias_step = 140
calc_step = 14
output_step = 14
group_size = 5

# Generate instructions
instructions = []
for i in range(groups_to_generate):
    bias = start_values["bias_start"] + i * bias_step
    calc = start_values["calc_start"] + i * calc_step
    output = start_values["output_start"] + i * output_step

    instructions.append(f"[9,14,{bias}]")
    instructions.append(f"[33,14,{calc},0]")
    instructions.append(f"[9,126,{bias + 14}]")
    instructions.append(f"[35,126,{calc},14]")
    instructions.append(f"[153,14,{calc},{output}]")

# Print all instructions
for instruction in instructions:
    print(instruction)
# Out:
# [9,14,16520]
# [33,14,1134,0]
# [9,126,16534]
# [35,126,1134,14]
# [153,14,1134,1918]
# [9,14,16660]
# [33,14,1148,0]
# [9,126,16674]
# [35,126,1148,14]
# [153,14,1148,1932]
# [9,14,16800]
# [33,14,1162,0]
# [9,126,16814]
# [35,126,1162,14]
# [153,14,1162,1946]
# [9,14,16940]
# [33,14,1176,0]
# [9,126,16954]
# [35,126,1176,14]
# [153,14,1176,1960]
# [9,14,17080]
# [33,14,1190,0]
# [9,126,17094]
# [35,126,1190,14]
# [153,14,1190,1974]
# [9,14,17220]
# [33,14,1204,0]
# [9,126,17234]
# [35,126,1204,14]
# [153,14,1204,1988]
# [9,14,17360]
# [33,14,1218,0]
# [9,126,17374]
# [35,126,1218,14]
# [153,14,1218,2002]
# [9,14,17500]
# [33,14,1232,0]
# [9,126,17514]
# [35,126,1232,14]
# [153,14,1232,2016]
# [9,14,17640]
# [33,14,1246,0]
# [9,126,17654]
# [35,126,1246,14]
# [153,14,1246,2030]
# [9,14,17780]
# [33,14,1260,0]
# [9,126,17794]
# [35,126,1260,14]
# [153,14,1260,2044]
# [9,14,17920]
# [33,14,1274,0]
# [9,126,17934]
# [35,126,1274,14]
# [153,14,1274,2058]
# [9,14,18060]
# [33,14,1288,0]
# ...

# %%
# Starting values for the sequence
bias_start = 12180
calc_start = 574
output_start = 1358

# Steps for each group
bias_step = 14
calc_step = 14
output_step = 14

# Groups to generate
groups_to_generate = 10

# Generate instructions
instructions = []
for i in range(groups_to_generate):
    bias = bias_start + i * bias_step  # Adjust for the second bias in each group
    calc = calc_start + i * calc_step
    output = output_start + i * output_step

    instructions.append(f"[9,14,{bias}]")
    instructions.append(f"[33,14,{calc},0]")
    instructions.append(f"[9,0,{bias + bias_step}]")
    instructions.append(f"[35,0,{calc},14]")
    instructions.append(f"[153,14,{calc},{output}]")

# Print all instructions
for instruction in instructions:
    print(instruction)
# Out:
# [9,14,12180]
# [33,14,574,0]
# [9,0,12194]
# [35,0,574,14]
# [153,14,574,1358]
# [9,14,12194]
# [33,14,588,0]
# [9,0,12208]
# [35,0,588,14]
# [153,14,588,1372]
# [9,14,12208]
# [33,14,602,0]
# [9,0,12222]
# [35,0,602,14]
# [153,14,602,1386]
# [9,14,12222]
# [33,14,616,0]
# [9,0,12236]
# [35,0,616,14]
# [153,14,616,1400]
# [9,14,12236]
# [33,14,630,0]
# [9,0,12250]
# [35,0,630,14]
# [153,14,630,1414]
# [9,14,12250]
# [33,14,644,0]
# [9,0,12264]
# [35,0,644,14]
# [153,14,644,1428]
# [9,14,12264]
# [33,14,658,0]
# [9,0,12278]
# [35,0,658,14]
# [153,14,658,1442]
# [9,14,12278]
# [33,14,672,0]
# [9,0,12292]
# [35,0,672,14]
# [153,14,672,1456]
# [9,14,12292]
# [33,14,686,0]
# [9,0,12306]
# [35,0,686,14]
# [153,14,686,1470]
# [9,14,12306]
# [33,14,700,0]
# [9,0,12320]
# [35,0,700,14]
# [153,14,700,1484]

# %%
# Starting values for the sequence
bias_start = 12320
calc_start = 714
output_start = 1498

# Steps for each group
bias_step = 140
calc_step = 14
output_step = 14

# Groups to generate
groups_to_generate = 30

# Generate instructions
instructions = []
for i in range(groups_to_generate):
    bias = bias_start + i * bias_step  # Adjust for the second bias in each group
    calc = calc_start + i * calc_step
    output = output_start + i * output_step

    instructions.append(f"[9,14,{bias}]")
    instructions.append(f"[33,14,{calc},0]")
    instructions.append(f"[9,126,{bias + calc_step}]")
    instructions.append(f"[35,126,{calc},14]")
    instructions.append(f"[153,14,{calc},{output}]")

# Print all instructions
for instruction in instructions:
    print(instruction)
# Out:
# [9,14,12320]
# [33,14,714,0]
# [9,126,12334]
# [35,126,714,14]
# [153,14,714,1498]
# [9,14,12460]
# [33,14,728,0]
# [9,126,12474]
# [35,126,728,14]
# [153,14,728,1512]
# [9,14,12600]
# [33,14,742,0]
# [9,126,12614]
# [35,126,742,14]
# [153,14,742,1526]
# [9,14,12740]
# [33,14,756,0]
# [9,126,12754]
# [35,126,756,14]
# [153,14,756,1540]
# [9,14,12880]
# [33,14,770,0]
# [9,126,12894]
# [35,126,770,14]
# [153,14,770,1554]
# [9,14,13020]
# [33,14,784,0]
# [9,126,13034]
# [35,126,784,14]
# [153,14,784,1568]
# [9,14,13160]
# [33,14,798,0]
# [9,126,13174]
# [35,126,798,14]
# [153,14,798,1582]
# [9,14,13300]
# [33,14,812,0]
# [9,126,13314]
# [35,126,812,14]
# [153,14,812,1596]
# [9,14,13440]
# [33,14,826,0]
# [9,126,13454]
# [35,126,826,14]
# [153,14,826,1610]
# [9,14,13580]
# [33,14,840,0]
# [9,126,13594]
# [35,126,840,14]
# [153,14,840,1624]
# [9,14,13720]
# [33,14,854,0]
# [9,126,13734]
# [35,126,854,14]
# [153,14,854,1638]
# [9,14,13860]
# [33,14,868,0]
# [9,126,13874]
# [35,126,868,14]
# ...
